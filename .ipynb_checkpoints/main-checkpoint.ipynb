# %%
import os
import json
import requests
import pandas as pd
import numpy as np
import datetime
from copy import deepcopy

# %% [markdown]
# * Base url for api call for each user.

# %%
# give information about user's submission history
URL1 = "https://codeforces.com/api/user.status?handle="
# give informaiton about user's competition history
URL2 = "https://codeforces.com/api/user.rating?handle="

# %% [markdown]
# * Helper function to retrive data from server

# %%
def getSubData(uname):
    return json.loads(requests.get(URL1 + uname).content)['result']

def getCompiData(uname):
    return json.loads(requests.get(URL2 + uname).content)['result']

# %%
user = 'tourist'
subData = getSubData(user)
compiData = getCompiData(user)

# %%
print("Total Number of sumbission for user %s is %d" % (user,len(subData)))
# Out:
# Total Number of sumbission for user tourist is 1949

# %%
print("Total Number of compitition participated for user %s is %d" % (user,len(compiData)))
# Out:
# Total Number of compitition participated for user tourist is 148

# %% [markdown]
# # Data Mapping and Transformation

# %%
subData[1]
# Out:
# {'id': 52404688,
#  'contestId': 1119,
#  'creationTimeSeconds': 1554555169,
#  'relativeTimeSeconds': 4669,
#  'problem': {'contestId': 1119,
#   'index': 'F',
#   'name': 'Niyaz and Small Degrees',
#   'type': 'PROGRAMMING',
#   'points': 3250.0,
#   'rating': 2900,
#   'tags': ['data structures', 'dp', 'trees']},
#  'author': {'contestId': 1119,
#   'members': [{'handle': 'tourist'}],
#   'participantType': 'CONTESTANT',
#   'ghost': False,
#   'room': 33,
#   'startTimeSeconds': 1554550500},
#  'programmingLanguage': 'GNU C++17',
#  'verdict': 'WRONG_ANSWER',
#  'testset': 'PRETESTS',
#  'passedTestCount': 4,
#  'timeConsumedMillis': 46,
#  'memoryConsumedBytes': 3174400}

# %%
subData[0]
# Out:
# {'id': 52405024,
#  'contestId': 1119,
#  'creationTimeSeconds': 1554555284,
#  'relativeTimeSeconds': 4784,
#  'problem': {'contestId': 1119,
#   'index': 'F',
#   'name': 'Niyaz and Small Degrees',
#   'type': 'PROGRAMMING',
#   'points': 3250.0,
#   'rating': 2900,
#   'tags': ['data structures', 'dp', 'trees']},
#  'author': {'contestId': 1119,
#   'members': [{'handle': 'tourist'}],
#   'participantType': 'CONTESTANT',
#   'ghost': False,
#   'room': 33,
#   'startTimeSeconds': 1554550500},
#  'programmingLanguage': 'GNU C++17',
#  'verdict': 'OK',
#  'testset': 'TESTS',
#  'passedTestCount': 55,
#  'timeConsumedMillis': 732,
#  'memoryConsumedBytes': 72192000}

# %%
# map compiData based on their contesId
def mapCompiData(cdata):
    data = {}
    cdata_copy = deepcopy(cdata)
    for row in cdata_copy:
        id_ = row.pop('contestId')
        data[id_] = row
    return data

# %%
def mapSubmissions(sdata):
    data = {}
    sdata_copy = deepcopy(sdata)
    for sub in sdata_copy:
        name = str(sub['problem']['contestId']) + "_" + sub['problem']['index']
        if name not in data:
            data[name] = []
        data[name].append(sub)
    return data

# %%
mapped_sub_data = mapSubmissions(subData)

# %%
l = set()
for s in subData:
    l.add(s['author']['participantType'])
print(l)
# Out:
# {'VIRTUAL', 'PRACTICE', 'OUT_OF_COMPETITION', 'CONTESTANT'}

# %%
# adding each submission to corresponding compitition
def addSubToContest(cdata, sdata):
    contest_submissions = [d for d in sdata if d['author']['participantType'] in ['CONTESTANT', 'OUT_OF_COMPETITION'] ]
    cdata_copy = deepcopy(cdata)
    for sub in contest_submissions:
        if sub['contestId'] not in cdata_copy:
            continue
        contest = cdata_copy[sub['contestId']]
        
        if 'submissions' not in contest:
            contest['submissions'] = []
        contest['submissions'].append(sub)
    return cdata_copy

# %%
full_contest_data = addSubToContest(mapCompiData(compiData), subData)

# %%
ll = [(k,len(v['submissions']), v['contestName'], v['newRating']) for k,v in full_contest_data.items()]
ll.sort( key=lambda x:x[1], reverse=True)

# %% [markdown]
# # Plot 1:
# * This plot shows comparison between two users compititon rating.
# * It will allow user to track and compare their progress with other user from time to time.
# * Each user starts with 1500 rating.
# * This will allow one team member compare their rating and improve accordinly.
#
# ### Why we need this plot?
# * Contest history gives overall overview on how much and how fast you progressed over time.
# * Here we not only giving overview of competition rating change but other statistics related to each contest like number of submission in that contest, average number of try to took solve a problem etc.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
'''
* get_stats and get_stats_default are helper method to get data for hover text.
* both _default method is dependent on get_stats method, update in get_stats will
  also leads to update in _default method.
'''

def get_stats(date, data):
    for d in data.values():
        if date == datetime.datetime.fromtimestamp(float(d['ratingUpdateTimeSeconds'])):
            return [d['newRating'], len(d['submissions']), d['contestName']]
        
# this is default set of display stats.
def get_stats_default(date_, data):
    if len(data)>0:
        return (date_, data[-1][1], -1, 'Not Participated')
    else:
        return (date_, 1500, -1, 'Not Participated')
        
def plot_two_rating(username1,username2):
    compiData1 = getCompiData(username1)
    compiData2 = getCompiData(username2)
    
    subData1 = getSubData(username1)
    subData2 = getSubData(username2)
    
    full_contest_data1 = addSubToContest(mapCompiData(compiData1), subData1)
    full_contest_data2 = addSubToContest(mapCompiData(compiData2), subData2)
    
    date_user1 = sorted(list(set([datetime.datetime.fromtimestamp(float(i['ratingUpdateTimeSeconds'])) for i in full_contest_data1.values()])))
    date_user2 = sorted(list(set([datetime.datetime.fromtimestamp(float(i['ratingUpdateTimeSeconds'])) for i in full_contest_data2.values()])))

    total_dates = sorted(list(set(date_user1 + date_user2)))
    
    data1 = []
    data2 = []
    for date_ in total_dates:
        if date_ in date_user1:
            data1.append((date_, *get_stats(date_,full_contest_data1)))
        else:
            data1.append(get_stats_default(date_, data1))

        if date_ in date_user2:
            data2.append((date_, *get_stats(date_,full_contest_data2)))
        else:
            data2.append(get_stats_default(date_, data2))

    pldata1 = go.Scatter(
        x=[x[0] for x in data1], 
        y=[x[1] for x in data1], 
        text = ["Total Submission In contest: " + str(v[2]) 
                + "<br>Rating: " 
                + str(v[1])
                + "<br>Name: "
                + v[3]
                for v in data1],
        hoverinfo ='text',
        name=username1
    )
    pldata2 = go.Scatter(
        x=[x[0] for x in data2], 
        y=[x[1] for x in data2], 
        text = ["Total Submission In contest: " + str(v[2]) 
                + "<br>Rating: " 
                + str(v[1])
                + "<br>Name: "
                + v[3]
                for v in data2],
        hoverinfo ='text',
        name=username2
    )
    
    # setting up the 
    layout = dict(
        title='Contest rating comparision between ' + username1 + " and " + username2,
        xaxis=dict(
            rangeselector=dict(
                buttons=list([
                    dict(count=1,
                         label='1m',
                         step='month',
                         stepmode='backward'),
                    dict(count=6,
                         label='6m',
                         step='month',
                         stepmode='backward'),
                    dict(count=1,
                        label='1y',
                        step='year',
                        stepmode='backward'),
                    dict(step='all')
                ])
            ),
            rangeslider=dict(
                visible = True
            ),
            type='date'
        )
    )
    fig = dict(data=[pldata1,pldata2], layout=layout)
    return iplot(fig, filename = "Manually Set Range")

# %%
plot_two_rating('petr','tourist')
# Out:
# <div id="8292cc5d-5fde-435f-90cf-5e7a2906aa0c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8292cc5d-5fde-435f-90cf-5e7a2906aa0c", [{"hoverinfo": "text", "name": "petr", "text": ["Total Submission In contest: 5<br>Rating: 1625<br>Name: Codeforces Beta Round #2", "Total Submission In contest: 4<br>Rating: 1775<br>Name: Codeforces Beta Round #3", "Total Submission In contest: 5<br>Rating: 1891<br>Name: Codeforces Beta Round #5", "Total Submission In contest: 6<br>Rating: 1977<br>Name: Codeforces Beta Round #7", "Total Submission In contest: 6<br>Rating: 2046<br>Name: Codeforces Beta Round #8", "Total Submission In contest: 5<br>Rating: 2109<br>Name: Codeforces Beta Round #10", "Total Submission In contest: 8<br>Rating: 2126<br>Name: Codeforces Beta Round #11", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2126<br>Name: Not Participated", "Total Submission In contest: 6<br>Rating: 2183<br>Name: Codeforces Beta Round #36", "Total Submission In contest: -1<br>Rating: 2183<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2183<br>Name: Not Participated", "Total Submission In contest: 8<br>Rating: 2240<br>Name: Codeforces Beta Round #39", "Total Submission In contest: -1<br>Rating: 2240<br>Name: Not Participated", "Total Submission In contest: 8<br>Rating: 2279<br>Name: School Personal Contest #2 (Winter Computer School 2010/11)<br>-<br>Codeforces Beta Round #43 (ACM-ICPC Rules)", "Total Submission In contest: 7<br>Rating: 2320<br>Name: Codeforces Beta Round #48", "Total Submission In contest: 6<br>Rating: 2276<br>Name: Codeforces Beta Round #50", "Total Submission In contest: 5<br>Rating: 2310<br>Name: Codeforces Beta Round #51", "Total Submission In contest: -1<br>Rating: 2310<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2310<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2310<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2310<br>Name: Not Participated", "Total Submission In contest: 4<br>Rating: 2344<br>Name: Codeforces Beta Round #62", "Total Submission In contest: 5<br>Rating: 2391<br>Name: Codeforces Beta Round #64", "Total Submission In contest: 9<br>Rating: 2374<br>Name: Codeforces Beta Round #66", "Total Submission In contest: -1<br>Rating: 2374<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2374<br>Name: Not Participated", "Total Submission In contest: 4<br>Rating: 2416<br>Name: Codeforces Beta Round #71", "Total Submission In contest: 5<br>Rating: 2441<br>Name: Yandex.Algorithm Open 2011<br>Qualification 1", "Total Submission In contest: -1<br>Rating: 2441<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2441<br>Name: Not Participated", "Total Submission In contest: 6<br>Rating: 2504<br>Name: Yandex.Algorithm 2011<br>Round 1", "Total Submission In contest: 4<br>Rating: 2562<br>Name: Yandex.Algorithm 2011<br>Round 2", "Total Submission In contest: 6<br>Rating: 2573<br>Name: Codeforces Beta Round #73 (Div. 1 Only)", "Total Submission In contest: -1<br>Rating: 2573<br>Name: Not Participated", "Total Submission In contest: 5<br>Rating: 2566<br>Name: Codeforces Beta Round #77 (Div. 1 Only)", "Total Submission In contest: 8<br>Rating: 2588<br>Name: Yandex.Algorithm 2011<br>Finals", "Total Submission In contest: -1<br>Rating: 2588<br>Name: Not Participated", "Total Submission In contest: -1<br>Rating: 2588<br>Name: Not P ...

# %% [markdown]
# # Plot 2

# %%
mapped_sub_data['2_B'].sort(key=lambda x:x['relativeTimeSeconds'])

# %%
mapped_sub_data['2_B']
# Out:
# [{'id': 7421,
#   'contestId': 2,
#   'creationTimeSeconds': 1267118606,
#   'relativeTimeSeconds': 1406,
#   'problem': {'contestId': 2,
#    'index': 'B',
#    'name': 'The least round way',
#    'type': 'PROGRAMMING',
#    'rating': 2000,
#    'tags': ['dp', 'math']},
#   'author': {'contestId': 2,
#    'members': [{'handle': 'tourist'}],
#    'participantType': 'CONTESTANT',
#    'ghost': False,
#    'startTimeSeconds': 1267117200},
#   'programmingLanguage': 'Delphi',
#   'verdict': 'TIME_LIMIT_EXCEEDED',
#   'testset': 'TESTS',
#   'passedTestCount': 30,
#   'timeConsumedMillis': 5000,
#   'memoryConsumedBytes': 16691200},
#  {'id': 7476,
#   'contestId': 2,
#   'creationTimeSeconds': 1267118901,
#   'relativeTimeSeconds': 1701,
#   'problem': {'contestId': 2,
#    'index': 'B',
#    'name': 'The least round way',
#    'type': 'PROGRAMMING',
#    'rating': 2000,
#    'tags': ['dp', 'math']},
#   'author': {'contestId': 2,
#    'members': [{'handle': 'tourist'}],
#    'participantType': 'CONTESTANT',
#    'ghost': False,
#    'startTimeSeconds': 1267117200},
#   'programmingLanguage': 'Delphi',
#   'verdict': 'WRONG_ANSWER',
#   'testset': 'TESTS',
#   'passedTestCount': 34,
#   'timeConsumedMillis': 380,
#   'memoryConsumedBytes': 16691200},
#  {'id': 7531,
#   'contestId': 2,
#   'creationTimeSeconds': 1267119368,
#   'relativeTimeSeconds': 2168,
#   'problem': {'contestId': 2,
#    'index': 'B',
#    'name': 'The least round way',
#    'type': 'PROGRAMMING',
#    'rating': 2000,
#    'tags': ['dp', 'math']},
#   'author': {'contestId': 2,
#    'members': [{'handle': 'tourist'}],
#    'participantType': 'CONTESTANT',
#    'ghost': False,
#    'startTimeSeconds': 1267117200},
#   'programmingLanguage': 'Delphi',
#   'verdict': 'OK',
#   'testset': 'TESTS',
#   'passedTestCount': 37,
#   'timeConsumedMillis': 330,
#   'memoryConsumedBytes': 16691200}]

# %%
def get_topic_stat(data):
    d = {}
    for subs in data:
        tags = subs[0]['problem']['tags']
        subs.sort(key = lambda x: x['relativeTimeSeconds'])
        flag = 0
        for t in tags:
            if t not in d:
                d[t] = (0,0)
                
            for sub in subs:
                if flag:
                    break
                if sub['verdict'] == 'OK':
                    flag = 1
